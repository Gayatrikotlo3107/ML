# %% [markdown]
# ### Exercise 4: Clustering
# ##### (24 points) --> your total will divided by 4 to get 6 points for this exercise.
# ### Due Thursday, June 23rd at 11:59 pm
# ---
#
#                                 Mall Customer Segmentation
# ##### Objective:
# divide the customers into five various groups.
# Clustering based on 2 features (Annual Income in k$  and Spending Score) in order to visulaize or plot the clusters
#
#
# ##### Dataset Description:
#         You can find the dataset "Mall_Customers.csv" under the dataset  section on the Moodle.
#
# This Dataset has complete the information about Mall Customer Spending Score.
# * The Dataset contains five attributes and 200 instances.
# * The 1st attribute is Customer ID which has every Customer has Unique
# * The 2nd attribute is Gender which is of course male/female.
# * The 3rd attribute is age which is between 19 to 70 of different customers
# * The 4th attribute is Annual Income in k$ which have different customer have a different Income some have very low some have middle and some have very high income
# * The last attribute Spending Score which he spends on Mall.

# %% [markdown]
# ### Step to do:

# %% [markdown]
#         1. Import the necessary packages from scikit-learn (KMeans, AgglomerativeClustering, and silhouette_score). (2 points)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
import plotly as py
import plotly.graph_objs as go

# %% [markdown]
#         2. Read the Mall Customers dataset into the pandas DataFrame and display the last 10 samples. (2 points)

# %%
mc_df =pd.read_csv("Mall_Customers.csv")
mc_df.tail(10)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 190         191  Female   34                 103                      23
# 191         192  Female   32                 103                      69
# 192         193    Male   33                 113                       8
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %% [markdown]
#        3. Assign the two features Annual Income (k$)" and "Spending Score (1-100)" to X. (2 points)

# %%
X= mc_df[['Annual Income (k$)','Spending Score (1-100)']]

# %% [markdown]
#         4. Visualize the the two featuerse ("Annual Income (k$)" And "Spending Score (1-100)) to understand the data structure. (2 points)

# %%
# Visualize the data:

plt.figure(figsize=(10,6))

plt.scatter(mc_df['Annual Income (k$)'],mc_df['Spending Score (1-100)'], marker='o');
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('Scatter plot between Annual Income and Spending Score')
# Out:
# Text(0.5, 1.0, 'Scatter plot between Annual Income and Spending Score')

# %% [markdown]
#         6. implementation of k-means on the X features using K= 5. ( 2 points)

# %%
km = KMeans(5)
clusters = km.fit_predict(X)

# %% [markdown]
#         7. Plot the predicted clusters from k-means. ( 2 points)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X.values[:,0], X.values[:,1], c=ac_clusters)
plt.title("Mall customer segmentation from Agglomerative Clustering")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-118-ef172513fbb0> in <module>
#       1 plt.figure(figsize=(10,6))
#       2
# ----> 3 plt.scatter(clusters['Annual Income (k$)'],clusters['Spending Score (1-100)'], marker='o');
#       4 plt.xlabel('Annual Income (k$)')
#       5 plt.ylabel('Spending Score (1-100)')
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
#         8. compute and print the silhouette score of K-mean clustering method (2 point)

# %%
score = silhouette_score(X, labels, metric='euclidean')
print('Silhouetter Score: %.3f' % score)
# Out:
# Silhouetter Score: 0.554

# %% [markdown]
#         9. Implementation of Agglomerative Clustering on the X.
#
# You will implement the Agglomerative Clustering three times using three types of linkages (single, complete and average)

# %% [markdown]
# #### a - single linkages:
# * Implementation of Agglomerative Clustering with single linkages,  (1 point)
# * Plot the predicted clusters. (1 point)
# * compute the silhouette score  (1 point)

# %%
# Implementation of Agglomerative Clustering with single linkages
ac = AgglomerativeClustering( linkage='single')
ac_clusters = ac.fit_predict(X)

# %%
# Plot the predicted clusters
plt.scatter(X.values[:,0], X.values[:,1], c=ac_clusters)
plt.title("Mall customer segmentation from Agglomerative Clustering")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.show()

# %%
# compute and print the silhouette score
print("Agg Clustering: ", silhouette_score(X, ac_clusters))
# Out:
# Agg Clustering:  0.436370757302489

# %% [markdown]
# #### b - complete linkages:
# * Implementation of Agglomerative Clustering with complete linkages,  (1 point)
# * Plot the predicted clusters. (1 point)
# * compute the silhouette score  (1 point)

# %%
# Implementation of Agglomerative Clustering with complete linkages
ac1 = AgglomerativeClustering( linkage='complete')
ac_clusters_complete = ac1.fit_predict(X)

# %%
# Plot the predicted clusters
plt.figure(figsize=(10,6))
plt.scatter(X.values[:,0], X.values[:,1], c=ac_clusters_complete)
plt.title("Mall customer segmentation from Agglomerative Clustering")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.show()

# %%
# compute and print the silhouette score
print("Agg Clustering: ", silhouette_score(X, ac_clusters_complete))
# Out:
# Agg Clustering:  0.36706444723912895

# %% [markdown]
# 10. Compare the silhouette scores of each clustering method above.
# *  What do you observe about the model performances? (4 points)
#
# #### Write your answer here
# Silhouette score is used to evaluate the quality of clusters created using clustering algorithms such as K-Means in terms of how well samples are clustered with other samples that are similar to each other.
# The value of the Silhouette score varies from -1 to 1.
# If the score is 1, the cluster is dense and well-separated than other clusters.
# A value near 0 represents overlapping clusters with samples very close to the decision boundary of the neighboring clusters.
# A negative score -1 ,0 indicates that the samples might have got assigned to the wrong clusters.
# from the above the k means silhouette score is near to 1 which means the cluster is dense and well-separated than other clusters
